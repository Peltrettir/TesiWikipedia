# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('statistiche wikipedia.csv')
df.head()
# Out:
#       date   eng  it
# 0  2001/01    67   0
# 1  2001/02   229   0
# 2  2001/03   757   0
# 3  2001/04  1368   0
# 4  2001/05  2666   0

# %%
plt.plot(df['date'],df['eng'])

# %%
plt.plot(df['date'],df['it'])

# %%
plt.plot(df['date'],df['eng'],df['it'])
